# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('cubic_zirconia (1).csv')

# %%
df
# Out:
#           ID  carat        cut color clarity  depth  table     x     y     z  \
# 0          1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1          2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2          3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3          4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4          5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 26962  26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09
# 26963  26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74
# 26964  26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17
# 26965  26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60
# 26966  26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27
#
#        price
# 0        499
# 1        984
# ...

# %%
df.head()
# Out:
#    ID  carat        cut color clarity  depth  table     x     y     z  price
# 0   1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1   2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2   3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3   4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4   5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779

# %%
nm_df=df.select_dtypes('number')

# %%
nm_df
# Out:
#           ID  carat  depth  table     x     y     z  price
# 0          1   0.30   62.1   58.0  4.27  4.29  2.66    499
# 1          2   0.33   60.8   58.0  4.42  4.46  2.70    984
# 2          3   0.90   62.2   60.0  6.04  6.12  3.78   6289
# 3          4   0.42   61.6   56.0  4.82  4.80  2.96   1082
# 4          5   0.31   60.4   59.0  4.35  4.43  2.65    779
# ...      ...    ...    ...    ...   ...   ...   ...    ...
# 26962  26963   1.11   62.3   58.0  6.61  6.52  4.09   5408
# 26963  26964   0.33   61.9   55.0  4.44  4.42  2.74   1114
# 26964  26965   0.51   61.7   58.0  5.12  5.15  3.17   1656
# 26965  26966   0.27   61.8   56.0  4.19  4.20  2.60    682
# 26966  26967   1.25   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 8 columns]

# %%
df.describe()
# Out:
#                  ID         carat         depth         table             x  \
# count  26967.000000  26967.000000  26270.000000  26967.000000  26967.000000
# mean   13484.000000      0.798375     61.745147     57.456080      5.729854
# std     7784.846691      0.477745      1.412860      2.232068      1.128516
# min        1.000000      0.200000     50.800000     49.000000      0.000000
# 25%     6742.500000      0.400000     61.000000     56.000000      4.710000
# 50%    13484.000000      0.700000     61.800000     57.000000      5.690000
# 75%    20225.500000      1.050000     62.500000     59.000000      6.550000
# max    26967.000000      4.500000     73.600000     79.000000     10.230000
#
#                   y             z         price
# count  26967.000000  26967.000000  26967.000000
# mean       5.733569      3.538057   3939.518115
# std        1.166058      0.720624   4024.864666
# min        0.000000      0.000000    326.000000
# ...

# %%
nm_df.head()
# Out:
#    ID  carat  depth  table     x     y     z  price
# 0   1   0.30   62.1   58.0  4.27  4.29  2.66    499
# 1   2   0.33   60.8   58.0  4.42  4.46  2.70    984
# 2   3   0.90   62.2   60.0  6.04  6.12  3.78   6289
# 3   4   0.42   61.6   56.0  4.82  4.80  2.96   1082
# 4   5   0.31   60.4   59.0  4.35  4.43  2.65    779

# %%
nm_df.corr()
# Out:
#              ID     carat     depth     table         x         y         z  \
# ID     1.000000  0.003490 -0.001588  0.003817  0.004626  0.006844  0.001681
# carat  0.003490  1.000000  0.035364  0.181685  0.976368  0.941071  0.940640
# depth -0.001588  0.035364  1.000000 -0.298011 -0.018715 -0.024735  0.101624
# table  0.003817  0.181685 -0.298011  1.000000  0.196206  0.182346  0.148944
# x      0.004626  0.976368 -0.018715  0.196206  1.000000  0.962715  0.956606
# y      0.006844  0.941071 -0.024735  0.182346  0.962715  1.000000  0.928923
# z      0.001681  0.940640  0.101624  0.148944  0.956606  0.928923  1.000000
# price  0.002650  0.922416 -0.002569  0.126942  0.886247  0.856243  0.850536
#
#           price
# ID     0.002650
# carat  0.922416
# depth -0.002569
# table  0.126942
# x      0.886247
# y      0.856243
# z      0.850536
# price  1.000000

# %%
sns.heatmap(nm_df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# ID           0
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64

# %%
df.shape
# Out:
# (26967, 11)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (26967, 11)

# %%
df.columns
# Out:
# Index(['ID', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y',
#        'z', 'price'],
#       dtype='object')

# %%
col=['x','y','z','carat']

# %%
sns.scatterplot(data=df,x='x',y='price')
# Out:
# <Axes: xlabel='x', ylabel='price'>

# %%
sns.scatterplot(data=df,x='y',y='price')
# Out:
# <Axes: xlabel='y', ylabel='price'>

# %%
sns.scatterplot(data=df,x='z',y='price')
# Out:
# <Axes: xlabel='z', ylabel='price'>

# %%
sns.scatterplot(data=df,x='carat',y='price')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
X=df.drop(columns=['depth','table','price','cut',"ID"])

# %%
y=df['price']

# %%
X.head()
# Out:
#    carat color clarity     x     y     z
# 0   0.30     E     SI1  4.27  4.29  2.66
# 1   0.33     G      IF  4.42  4.46  2.70
# 2   0.90     E    VVS2  6.04  6.12  3.78
# 3   0.42     F     VS1  4.82  4.80  2.96
# 4   0.31     F    VVS1  4.35  4.43  2.65

# %%
color = {
    'D':6,
    'E':5,
    'F':4,
    'G':3,
    "H":2,
    "I":1,
    "J":0,
    
}

# %%
X.head(10)
# Out:
#    carat color clarity     x     y     z
# 0   0.30     E     SI1  4.27  4.29  2.66
# 1   0.33     G      IF  4.42  4.46  2.70
# 2   0.90     E    VVS2  6.04  6.12  3.78
# 3   0.42     F     VS1  4.82  4.80  2.96
# 4   0.31     F    VVS1  4.35  4.43  2.65
# 5   1.02     D     VS2  6.46  6.49  3.99
# 6   1.01     H     SI1  6.35  6.30  4.03
# 7   0.50     E     SI1  5.09  5.06  3.12
# 8   1.21     H     SI1  6.72  6.63  4.26
# 9   0.35     F     VS2  4.52  4.60  2.76

# %%
X['color']=X['color'].map(color)

# %%
X.head(10)
# Out:
#    carat  color clarity     x     y     z
# 0   0.30      5     SI1  4.27  4.29  2.66
# 1   0.33      3      IF  4.42  4.46  2.70
# 2   0.90      5    VVS2  6.04  6.12  3.78
# 3   0.42      4     VS1  4.82  4.80  2.96
# 4   0.31      4    VVS1  4.35  4.43  2.65
# 5   1.02      6     VS2  6.46  6.49  3.99
# 6   1.01      2     SI1  6.35  6.30  4.03
# 7   0.50      5     SI1  5.09  5.06  3.12
# 8   1.21      2     SI1  6.72  6.63  4.26
# 9   0.35      4     VS2  4.52  4.60  2.76

# %%
clarity = {}
l="I1,SI2,SI1,VS2,VS1,VVS2,VVS1,IF".split(",")
for i in l:
    clarity[i]=l.index(i)

# %%
clarity
# Out:
# {'I1': 0,
#  'SI2': 1,
#  'SI1': 2,
#  'VS2': 3,
#  'VS1': 4,
#  'VVS2': 5,
#  'VVS1': 6,
#  'IF': 7}

# %%
X['clarity']=X['clarity'].map(clarity)

# %%
X.head()
# Out:
#    carat  color  clarity     x     y     z
# 0   0.30      5        2  4.27  4.29  2.66
# 1   0.33      3        7  4.42  4.46  2.70
# 2   0.90      5        5  6.04  6.12  3.78
# 3   0.42      4        4  4.82  4.80  2.96
# 4   0.31      4        6  4.35  4.43  2.65

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()
cut= lb.fit_transform(df['cut'])

# %%
from sklearn.model_selection import train_test_split

# %%
trainx,testx,trainy,testy = train_test_split(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
mod = LinearRegression()

# %%
mod.fit(trainx,trainy)
# Out:
# LinearRegression()

# %%
mod.coef_
# Out:
# array([10419.27020954,   329.44490754,   523.38186308,  -657.92095279,
#           43.15015544,  -184.96638482])

# %%
y[:5]
# Out:
# 0     499
# 1     984
# 2    6289
# 3    1082
# 4     779
# Name: price, dtype: int64

# %%
mod.predict([[1,0.30,5,2,4.27,4.29,2.66],[2,0.33,3,7,4.42,4.46,2.70]])
# Out:
# C:\Users\prath\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 mod.predict([[1,	0.30,5,2,4.27,4.29,2.66],[2,	0.33,3,7,4.42,4.46,2.70]])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:269, in LinearModel._decision_function(self, X)
# ...

# %%
from sklearn.metrics import r2_score

# %%
r2_score(mod.predict(testx),testy)
# Out:
# 0.898197462427409

# %%
carat=int(input())
color=int(input())
clarity=int(input())
x=int(input())
y=int(input())	
z=int(input())
mod.predict([[carat,color,clarity,x,y,z]])
# Out:
#  k
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 carat=int(input())
#       2 color=int(input())
#       3 clarity=int(input())
#
# ValueError: invalid literal for int() with base 10: 'k'

# %%
clarity.keys()

# %%
import pickle

# %%
file = open("diamondsss.pkl","wb")

# %%
pickle.dump(mod,file)

# %%
mod
# Out:
# LinearRegression()
